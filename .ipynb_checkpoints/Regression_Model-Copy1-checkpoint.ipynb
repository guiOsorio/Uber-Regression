# %%
import math
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import logit, probit, ols

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, confusion_matrix

# %%
# Load Data
data = pd.read_excel('./Uber_Data.xlsx', sheet_name=2)

# %% [markdown]
# # EXPLORATORY ANALYSIS / DATA CLEANING

# %%
data.head()
# Out:
#   city_id        period_start wait_time  treat  commute  trips_pool  \
# 0  Boston 2018-02-19 07:00:00    2 mins  False     True        1415
# 1  Boston 2018-02-19 09:40:00    5 mins   True    False        1461
# 2  Boston 2018-02-19 12:20:00    2 mins  False    False        1362
# 3  Boston 2018-02-19 15:00:00    5 mins   True     True        1984
# 4  Boston 2018-02-19 17:40:00    2 mins  False    False        1371
#
#    trips_express  rider_cancellations  total_driver_payout  total_matches  \
# 0           3245                  256         34458.411634           3372
# 1           2363                  203         29764.349821           2288
# 2           2184                  118         27437.367363           2283
# 3           3584                  355         44995.452993           4035
# 4           2580                  181         27583.955295           2200
#
#    total_double_matches
# 0                  1476
# 1                  1275
# 2                   962
# 3                  2021
# 4                   979

# %%
data.columns
# Out:
# Index(['city_id', 'period_start', 'wait_time', 'treat', 'commute',
#        'trips_pool', 'trips_express', 'rider_cancellations',
#        'total_driver_payout', 'total_matches', 'total_double_matches'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city_id               126 non-null    object
#  1   period_start          126 non-null    datetime64[ns]
#  2   wait_time             126 non-null    object
#  3   treat                 126 non-null    bool
#  4   commute               126 non-null    bool
#  5   trips_pool            126 non-null    int64
#  6   trips_express         126 non-null    int64
#  7   rider_cancellations   126 non-null    int64
#  8   total_driver_payout   126 non-null    float64
#  9   total_matches         126 non-null    int64
#  10  total_double_matches  126 non-null    int64
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(5), object(2)
# memory usage: 9.2+ KB

# %%
data.select_dtypes(include = 'object').nunique()

# All data is from Boston
# Wait times can be of 2 mins or 5 mins
# Out:
# city_id      1
# wait_time    2
# dtype: int64

# %%
sumstats=data.describe()
sumstats.round(decimals=2)
# Out:
#        trips_pool  trips_express  rider_cancellations  total_driver_payout  \
# count      126.00         126.00               126.00               126.00
# mean      1408.01        2515.52               177.74             28237.22
# std        257.93         497.69                51.63              5450.95
# min        771.00        1638.00                95.00             18769.99
# 25%       1248.25        2225.00               147.75             24721.89
# 50%       1397.00        2427.50               166.00             27352.84
# 75%       1580.25        2661.75               187.25             30586.11
# max       2241.00        4507.00               355.00             48600.42
#
#        total_matches  total_double_matches
# count         126.00                126.00
# mean         2535.75               1322.44
# std           607.57                350.32
# min          1588.00                728.00
# 25%          2171.75               1059.75
# 50%          2361.00               1282.50
# 75%          2714.50               1481.75
# max          5005.00               2739.00

# %% [markdown]
# #### Uber Pool
# Riders share their ride with other riders (they are together in the same car), for a cheaper price.
#
# #### Uber Express
# Equivalent to Uber Pool in terms of sharing a ride with other riders, but riders may also be required to have to walk a short distance before the ride (to the meet up spot with the driver), and after the ride (to reach their destination). This results in Uber being able to charge an even lower price for the service.

# %%
print(sns.relplot(x="period_start", y="rider_cancellations", kind="line", ci="sd", data=data))
print(sns.relplot(data=data, x="period_start", y="rider_cancellations", col="treat", hue="rider_cancellations",
            kind="scatter"))

## Check weekends? Maybe cancellations are higher on the weekends.
## Then check correlation with total_matches
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x000001C19394B3A0>
# <seaborn.axisgrid.FacetGrid object at 0x000001C193676B50>

# %% [markdown]
# ### Creation of new weekend variable

# %%
#### Explore weekend or not weekend variable and look for changes
# Create new variable to represent the day of the week
data['weekday'] = data['period_start'].dt.dayofweek

# Create weekend (1) or not weekend (0) binary variable
def id_weekend(row):
    if row in (5,6):
        return 1 # weekend day -- Saturday or Sunday
    else:
        return 0 # not weekend day
data['weekend'] = data['weekday'].apply(lambda row: id_weekend(row))

# Check distribution of new categorical variables
print(sns.countplot(data = data, x = 'weekday'))

## data is equally spread between the days of the week

# Drop 'weekday' column
data = data.drop(columns = {'weekday'})

data['weekend']
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 121    1
# 122    1
# 123    1
# 124    0
# 125    0
# Name: weekend, Length: 126, dtype: int64

# %%
# Check distribution of new categorical variables
sns.countplot(data = data, x = 'weekend')
# Out:
# <AxesSubplot:xlabel='weekend', ylabel='count'>

# %%
sns.catplot(x="treat", y="rider_cancellations", hue="treat", kind="bar", data=data)

# %%
#divide the data into 2 dataframes: one for the treatment group and one for the control group. Use the "treatment" variable as the decision rule to divide the data set
df_treatment = data[data['treat']]
df_control = data[data['treat'] == False]

# %%
#check to the dataframe to make sure that only the treatment group is in the treatment dataframe
df_treatment
# Out:
#     city_id        period_start wait_time  treat  commute  trips_pool  \
# 1    Boston 2018-02-19 09:40:00    5 mins   True    False        1461
# 3    Boston 2018-02-19 15:00:00    5 mins   True     True        1984
# 5    Boston 2018-02-19 20:20:00    5 mins   True    False        1401
# 7    Boston 2018-02-20 01:40:00    5 mins   True    False        1691
# 9    Boston 2018-02-20 07:00:00    5 mins   True     True        1815
# ..      ...                 ...       ...    ...      ...         ...
# 117  Boston 2018-03-04 07:00:00    5 mins   True    False        1515
# 119  Boston 2018-03-04 12:20:00    5 mins   True    False        1818
# 121  Boston 2018-03-04 17:40:00    5 mins   True    False        1718
# 123  Boston 2018-03-04 23:00:00    5 mins   True    False        1157
# 125  Boston 2018-03-05 04:20:00    5 mins   True    False        1360
#
#      trips_express  rider_cancellations  total_driver_payout  total_matches  \
# 1             2363                  203         29764.349821           2288
# 3             3584                  355         44995.452993           4035
# 5             2022                  135         23888.110848           2066
# 7             2018                  150         25794.869920           1918
# 9             2539                  284         34047.473898           2624
# ..             ...                  ...                  ...            ...
# 117           2059                  129         22995.159002           1828
# 119           1970                  204         24339.583561           1974
# 121           2655                  173         28288.521151           2600
# 123           2359                  154         23525.115952           2323
# 125           2421                  196         26017.526022           2361
#
#      total_double_matches  weekend
# 1                    1275        0
# 3                    2021        0
# 5                    1062        0
# 7                    1281        0
# 9                    1565        0
# ..                    ...      ...
# 117                  1063        1
# 119                  1510        1
# 121                  1361        1
# 123                  1473        1
# 125                  1015        0
#
# [63 rows x 12 columns]

# %%
def check_mannwhitney(var):
    u_statistic, p_value = stats.mannwhitneyu(df_treatment[var], df_control[var])
    print(f'U-Statistic ({var}): ', u_statistic)
    print(f'p-value: ({var})', p_value)
    if p_value <= 0.05:
        print('We can reject the null hypothesis. The variable significantly differs by treatment.')
    else:
        print('We cannot reject the null hypothesis. The variable does not significantly differ by treatment.')
    print('')

# %%
#conduct a mann-whitney test to test whether a variable, in this example rider_cancellations, differs by treatment.
#is the number of rider_cancellations statistically significantly different in the treatment group than the control group?

print('Using an alpha of 0.05: \n')
for var_name in df_treatment:
    if var_name not in ('city_id', 'period_start', 'wait_time', 'treat'):
        print(f'Is the {var_name} variable statistically significantly different in the treatment group than the control group?')
        check_mannwhitney(var_name)
# Out:
# Using an alpha of 0.05:
#
# Is the commute variable statistically significantly different in the treatment group than the control group?
# U-Statistic (commute):  1984.5
# p-value: (commute) 1.0
# We cannot reject the null hypothesis. The variable does not significantly differ by treatment.
#
# Is the trips_pool variable statistically significantly different in the treatment group than the control group?
# U-Statistic (trips_pool):  2477.5
# p-value: (trips_pool) 0.01625941824302551
# We can reject the null hypothesis. The variable significantly differs by treatment.
#
# Is the trips_express variable statistically significantly different in the treatment group than the control group?
# U-Statistic (trips_express):  1477.5
# p-value: (trips_express) 0.013460836315667414
# We can reject the null hypothesis. The variable significantly differs by treatment.
#
# Is the rider_cancellations variable statistically significantly different in the treatment group than the control group?
# U-Statistic (rider_cancellations):  2602.0
# p-value: (rider_cancellations) 0.002604848374553357
# We can reject the null hypothesis. The variable significantly differs by treatment.
#
# Is the total_driver_payout variable statistically significantly different in the treatment group than the control group?
# U-Statistic (total_driver_payout):  1529.0
# p-value: (total_driver_payout) 0.02641646528378862
# We can reject the null hypothesis. The variable significantly differs by treatment.
#
# Is the total_matches variable statistically significantly different in the treatment group than the control group?
# U-Statistic (total_matches):  1542.0
# p-value: (total_matches) 0.03103549421828295
# We can reject the null hypothesis. The variable significantly differs by treatment.
#
# Is the total_double_matches variable statistically significantly different in the treatment group than the control group?
# U-Statistic (total_double_matches):  2336.5
# p-value: (total_double_matches) 0.08633652208152091
# We cannot reject the null hypothesis. The variable does not significantly differ by treatment.
#
# Is the weekend variable statistically significantly different in the treatment group than the control group?
# U-Statistic (weekend):  1984.5
# p-value: (weekend) 1.0
# We cannot reject the null hypothesis. The variable does not significantly differ by treatment.

# %% [markdown]
# #### Variables which differ between groups:
#  - trips_pool
#  - trips_express
#  - rider_cancellations
#  - total_driver_payout
#  - total_matches

# %% [markdown]
# ### Explore dubious relationships to find potential multicollinearity issues
# ##### Plot ind variables against each other to check for multicollinearity (and correlation matrix)
# ##### - remove one from every highly correlated pair

# %%
# total_matches and total_driver_payout
sns.regplot(x='total_matches', y='total_driver_payout', data=data)

## Positively correlated --> REMOVE one of the variables
# Out:
# <AxesSubplot:xlabel='total_matches', ylabel='total_driver_payout'>

# %%
# commute and total_matches
sns.regplot(x='total_matches', y='commute', data=data)

## Potentially correlated. Commute hours tend to have more matches --> REMOVE one of the variables
# Out:
# <AxesSubplot:xlabel='total_matches', ylabel='commute'>

# %%
# trips_pool and trips_express
sns.regplot(x='trips_pool', y='trips_express', data=data)

## Don't seem to be correlated
# Out:
# <AxesSubplot:xlabel='trips_pool', ylabel='trips_express'>

# %%
# Correlation matrix of numerical data
data.select_dtypes(exclude = 'object').corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_31ae7_row0_col0, #T_31ae7_row1_col1, #T_31ae7_row2_col2, #T_31ae7_row3_col3, #T_31ae7_row4_col4, #T_31ae7_row5_col5, #T_31ae7_row6_col6, #T_31ae7_row7_col7, #T_31ae7_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_31ae7_row0_col1, #T_31ae7_row0_col8, #T_31ae7_row6_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_31ae7_row0_col2, #T_31ae7_row1_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_31ae7_row0_col3, #T_31ae7_row0_col5, #T_31ae7_row0_col6, #T_31ae7_row1_col8, #T_31ae7_row3_col0, #T_31ae7_row5_col0, #T_31ae7_row8_col1, #T_31ae7_row8_col2, #T_31ae7_row8_col4, #T_31ae7_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_31ae7_row0_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_31ae7_row0_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col0, #T_31ae7_row8_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col3, #T_31ae7_row4_col6, #T_31ae7_row5_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col6 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_31ae7_row1_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_31ae7_row2_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_31ae7_row2_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_31ae7_row2_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_31ae7_row2_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_31ae7_row2_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_31ae7_row2_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_31ae7_row2_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_31ae7_row2_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col1, #T_31ae7_row6_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col4, #T_31ae7_row7_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col5, #T_31ae7_row5_col3, #T_31ae7_row6_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col6, #T_31ae7_row6_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col7, #T_31ae7_row4_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_31ae7_row3_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_31ae7_row4_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_31ae7_row4_col1 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_31ae7_row4_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_31ae7_row4_col3 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_31ae7_row4_col7, #T_31ae7_row7_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_31ae7_row4_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_31ae7_row5_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_31ae7_row5_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_31ae7_row5_col6 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_31ae7_row5_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_31ae7_row5_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_31ae7_row6_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_31ae7_row6_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_31ae7_row6_col7 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_31ae7_row6_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_31ae7_row7_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_31ae7_row7_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_31ae7_row7_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_31ae7_row7_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_31ae7_row7_col5 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_31ae7_row7_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_31ae7_row8_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_31ae7_row8_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_31ae7_row8_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31ae7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treat</th>
#       <th class="col_heading level0 col1" >commute</th>
#       <th class="col_heading level0 col2" >trips_pool</th>
#       <th class="col_heading level0 col3" >trips_express</th>
#       <th class="col_heading level0 col4" >rider_cancellations</th>
#       <th class="col_heading level0 col5" >total_driver_payout</th>
#       <th class="col_heading level0 col6" >total_matches</th>
#       <th class="col_heading level0 col7" >total_double_matches</th>
#       <th class="col_heading level0 col8" >weekend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31ae7_level0_row0" class="row_heading level0 row0" >treat</th>
#       <td id="T_31ae7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_31ae7_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_31ae7_row0_col2" class="data row0 col2" >0.205098</td>
#       <td id="T_31ae7_row0_col3" class="data row0 col3" >-0.193948</td>
#       <td id="T_31ae7_row0_col4" class="data row0 col4" >0.240905</td>
#       <td id="T_31ae7_row0_col5" class="data row0 col5" >-0.194136</td>
#       <td id="T_31ae7_row0_col6" class="data row0 col6" >-0.161037</td>
#       <td id="T_31ae7_row0_col7" class="data row0 col7" >0.101125</td>
#       <td id="T_31ae7_row0_col8" class="data row0 col8" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31ae7_level0_row1" class="row_heading level0 row1" >commute</th>
#       <td id="T_31ae7_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_31ae7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_31ae7_row1_col2" class="data row1 col2" >0.204911</td>
#       <td id="T_31ae7_row1_col3" class="data row1 col3" >0.736340</td>
#       <td id="T_31ae7_row1_col4" class="data row1 col4" >0.821942</td>
#       <td id="T_31ae7_row1_col5" class="data row1 col5" >0.751820</td>
#       <td id="T_31ae7_row1_col6" class="data row1 col6" >0.786761</td>
#       <td id="T_31ae7_row1_col7" class="data row1 col7" >0.595798</td>
#       <td id="T_31ae7_row1_col8" class="data row1 col8" >-0.274721</td>
#     </tr>
#     <tr>
#       <th id="T_31ae7_level0_row2" class="row_heading level0 row2" >trips_pool</th>
#       <td id="T_31ae7_row2_col0" class="data row2 col0" >0.205098</td>
#       <td id="T_31ae7_row2_col1" class="data row2 col1" >0.204911</td>
#       <td id="T_31ae7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_31ae7_row2_col3" class="data row2 col3" >0.057703</td>
#       <td id="T_31ae7_row2_col4" class="data row2 col4" >0.372003</td>
#       <td id="T_31ae7_row2_col5" class="data row2 col5" >0.449967</td>
#       <td id="T_31ae7_row2_col6" class="data row2 col6" >0.085050</td>
#       <td id="T_31ae7_row2_col7" class="data row2 col7" >0.134487</td>
#       <td id="T_31ae7_row2_col8" class="data row2 col8" >-0.168861</td>
#     </tr>
#     <tr>
#       <th id="T_31ae7_level0_row3" class="row_heading level0 row3" >trips_express</th>
#       <td id="T_31ae7_row3_col0" class="data row3 col0" >-0.193948</td>
#       <td id="T_31ae7_row3_col1" class="data row3 col1" >0.736340</td>
#       <td id="T_31ae7_row3_col2" class="data row3 col2" >0.057703</td>
#       <td id="T_31ae7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_31ae7_row3_col4" class="data row3 col4" >0.717460</td>
#       <td id="T_31ae7_row3_col5" class="data row3 col5" >0.795741</td>
#       <td id="T_31ae7_row3_col6" class="data row3 col6" >0.961497</td>
#       <td id="T_31ae7_row3_col7" class="data row3 col7" >0.757889</td>
#       <td id="T_31ae7_row3_col8" class="data row3 col8" >-0.082074</td>
#     </tr>
#     <tr>
#       <th id="T_31ae7_level0_row4" class="row_heading level0 row4" >rider_cancellations</th>
#       <td id="T_31ae7_row4_col0" class="data row4 co

# %% [markdown]
# #### Conclusions (variables to remove > 0.7 correlation)
#  - commute OR trips_express
#  - commute OR total_driver_payout
#  - commute OR total_matches
#  - trips_express OR total_driver_payout
#  - trips_express OR total_matches
#  - trips_express OR total_double_matches
#  - total_driver_payout OR total_matches
#  - total_matches OR total_double_matches

# %% [markdown]
# ### Relationship between independent variables and the dependent variable

# %%
# Generate scatter plots for each numerical variable against the dependent/target variable
for col in data.columns:
    if col in ('commute','trips_pool', 'trips_express', 'total_driver_payout', 'total_matches', 'total_double_matches'):
        sns.scatterplot(data = data, x = col, y = 'rider_cancellations')
        plt.show()

# %% [markdown]
# #### Relationships between each independent variable and the dependent variable based on scatter plots
#
#  - commute -> positive correlation
#  - trips_pool -> weak positive correlation
#  - trips_express -> positive correlation
#  - total_driver_payout -> positive correlation
#  - total_matches -> positive correlation
#  - total_double_matches -> positive correlation

# %% [markdown]
# ## FIT MODEL - statsmodels

# %%
model1 = ols("rider_cancellations ~ treat + trips_pool + total_matches + weekend", data).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     rider_cancellations   R-squared:                       0.756
# Model:                             OLS   Adj. R-squared:                  0.748
# Method:                  Least Squares   F-statistic:                     93.55
# Date:                 Fri, 20 May 2022   Prob (F-statistic):           4.39e-36
# Time:                         08:23:28   Log-Likelihood:                -586.47
# No. Observations:                  126   AIC:                             1183.
# Df Residuals:                      121   BIC:                             1197.
# Df Model:                            4
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -61.0301     16.194     -3.769      0.000     -93.090     -28.970
# treat[T.True]    32.7384      4.804      6.815      0.000      23.227      42.250
# trips_pool        0.0442      0.009      4.713      0.000       0.026       0.063
# total_matches     0.0648      0.004     16.539      0.000       0.057       0.073
# weekend         -14.1772      5.216     -2.718      0.008     -24.503      -3.852
# ==============================================================================
# Omnibus:                        3.125   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                2.929
# Skew:                           0.373   Prob(JB):                        0.231
# Kurtosis:                       2.979   Cond. No.                     2.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### EVALUATE MODEL

# %% [markdown]
#  - Adjusted R-Squared -> 74.8%
#      - this model explains 74.8% of the variance in the rider_cancellations variable
#  - P-value -> below 0.05 for all variables used
#      - all variables used are statistically significant using a significance level of 5%

# %% [markdown]
# #### Residual plot of errors (y), ind variable (x) - zero mean of errors and autocorrelation of errors -- should average to 0

# %%
# Residual plot for model1
sns.scatterplot(x = model1.fittedvalues, y = model1.resid)
plt.ylabel('residual')
plt.axhline(0)

## The residuals seems to average to around 0, showing this does not represent a problem in model1

# %%
#define figure size
fig = plt.figure(figsize=(12,8))

#produce regression plots
fig = sm.graphics.plot_regress_exog(model1, 'trips_pool', fig=fig)

# %%
#define figure size
fig2 = plt.figure(figsize=(12,8))

#produce regression plots
fig2 = sm.graphics.plot_regress_exog(model1, 'total_matches', fig=fig2)

# %% [markdown]
# ## TREATMENT GROUP (5 MINUTES)

# %%
# Generate scatter plots for each numerical variable in the 5 minute dataframe against the dependent variable
for col in df_treatment.columns:
    if col in ('trips_pool', 'trips_express', 'total_driver_payout', 'total_matches', 'total_double_matches'):
        sns.scatterplot(data = df_treatment, x = 'rider_cancellations', y = col)
        plt.show()

# %% [markdown]
# #### Relationships between each independent variable and the dependent variable based on scatter plots
#
#  - trips_pool ->  non-linear relationship (REMOVE)
#  - trips_express -> linear relationship
#  - total_driver_payout -> linear relationship
#  - total_matches -> linear relationship
#  - total_double_matches -> linear relationship

# %% [markdown]
# ### Check for Multicollinearity

# %%
# Correlation matrix of numerical data
df_treatment.select_dtypes(exclude = 'object').corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_7f55b_row0_col0, #T_7f55b_row0_col1, #T_7f55b_row0_col2, #T_7f55b_row0_col3, #T_7f55b_row0_col4, #T_7f55b_row0_col5, #T_7f55b_row0_col6, #T_7f55b_row0_col7, #T_7f55b_row0_col8, #T_7f55b_row1_col0, #T_7f55b_row2_col0, #T_7f55b_row3_col0, #T_7f55b_row4_col0, #T_7f55b_row5_col0, #T_7f55b_row6_col0, #T_7f55b_row7_col0, #T_7f55b_row8_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col1, #T_7f55b_row2_col2, #T_7f55b_row3_col3, #T_7f55b_row4_col4, #T_7f55b_row5_col5, #T_7f55b_row6_col6, #T_7f55b_row7_col7, #T_7f55b_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col2, #T_7f55b_row2_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_7f55b_row1_col4 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col5, #T_7f55b_row3_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_7f55b_row1_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7f55b_row1_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7f55b_row2_col1, #T_7f55b_row4_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7f55b_row2_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_7f55b_row2_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_7f55b_row2_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_7f55b_row2_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7f55b_row2_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col2, #T_7f55b_row5_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col4, #T_7f55b_row4_col6, #T_7f55b_row5_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col6, #T_7f55b_row6_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col7 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_7f55b_row3_col8, #T_7f55b_row7_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7f55b_row4_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_7f55b_row4_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_7f55b_row4_col5, #T_7f55b_row6_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_7f55b_row4_col7 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_7f55b_row4_col8, #T_7f55b_row8_col1, #T_7f55b_row8_col2, #T_7f55b_row8_col3, #T_7f55b_row8_col4, #T_7f55b_row8_col5, #T_7f55b_row8_col6, #T_7f55b_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7f55b_row5_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_7f55b_row5_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_7f55b_row5_col3 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_7f55b_row5_col6 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_7f55b_row5_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_7f55b_row6_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7f55b_row6_col4 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_7f55b_row6_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_7f55b_row6_col7, #T_7f55b_row7_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_7f55b_row6_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7f55b_row7_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_7f55b_row7_col3 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_7f55b_row7_col5 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_7f55b_row7_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_7f55b_row7_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f55b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treat</th>
#       <th class="col_heading level0 col1" >commute</th>
#       <th class="col_heading level0 col2" >trips_pool</th>
#       <th class="col_heading level0 col3" >trips_express</th>
#       <th class="col_heading level0 col4" >rider_cancellations</th>
#       <th class="col_heading level0 col5" >total_driver_payout</th>
#       <th class="col_heading level0 col6" >total_matches</th>
#       <th class="col_heading level0 col7" >total_double_matches</th>
#       <th class="col_heading level0 col8" >weekend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f55b_level0_row0" class="row_heading level0 row0" >treat</th>
#       <td id="T_7f55b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_7f55b_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_7f55b_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_7f55b_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_7f55b_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_7f55b_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_7f55b_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_7f55b_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_7f55b_row0_col8" class="data row0 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f55b_level0_row1" class="row_heading level0 row1" >commute</th>
#       <td id="T_7f55b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_7f55b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7f55b_row1_col2" class="data row1 col2" >0.127894</td>
#       <td id="T_7f55b_row1_col3" class="data row1 col3" >0.724559</td>
#       <td id="T_7f55b_row1_col4" class="data row1 col4" >0.919836</td>
#       <td id="T_7f55b_row1_col5" class="data row1 col5" >0.743293</td>
#       <td id="T_7f55b_row1_col6" class="data row1 col6" >0.787465</td>
#       <td id="T_7f55b_row1_col7" class="data row1 col7" >0.606904</td>
#       <td id="T_7f55b_row1_col8" class="data row1 col8" >-0.274721</td>
#     </tr>
#     <tr>
#       <th id="T_7f55b_level0_row2" class="row_heading level0 row2" >trips_pool</th>
#       <td id="T_7f55b_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_7f55b_row2_col1" class="data row2 col1" >0.127894</td>
#       <td id="T_7f55b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7f55b_row2_col3" class="data row2 col3" >0.026416</td>
#       <td id="T_7f55b_row2_col4" class="data row2 col4" >0.251743</td>
#       <td id="T_7f55b_row2_col5" class="data row2 col5" >0.467349</td>
#       <td id="T_7f55b_row2_col6" class="data row2 col6" >0.058743</td>
#       <td id="T_7f55b_row2_col7" class="data row2 col7" >0.084748</td>
#       <td id="T_7f55b_row2_col8" class="data row2 col8" >-0.091509</td>
#     </tr>
#     <tr>
#       <th id="T_7f55b_level0_row3" class="row_heading level0 row3" >trips_express</th>
#       <td id="T_7f55b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_7f55b_row3_col1" class="data row3 col1" >0.724559</td>
#       <td id="T_7f55b_row3_col2" class="data row3 col2" >0.026416</td>
#       <td id="T_7f55b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7f55b_row3_col4" class="data row3 col4" >0.804068</td>
#       <td id="T_7f55b_row3_col5" class="data row3 col5" >0.754115</td>
#       <td id="T_7f55b_row3_col6" class="data row3 col6" >0.961547</td>
#       <td id="T_7f55b_row3_col7" class="data row3 col7" >0.764661</td>
#       <td id="T_7f55b_row3_col8" class="data row3 col8" >-0.109420</td>
#     </tr>
#     <tr>
#       <th id="T_7f55b_level0_row4" class="row_heading level0 row4" >rider_cancellations</th>
#       <td id="T_7f55b_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_7f55b_row4_col1" class="data row4 col1" >0.919836</td>
#       <td id="T_7f55b_row4_col2" class="data row4 col2" >0.251743</td>
#       <td id="T_7f55b_row4_col3" class="data row4 col3" >0.804068</td>
#       <td id="T_7f55b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7f55b_row4_col5" class="data row4 col5" >0.805774</td>
#       <td id="T_7f55b_row4_col6" class="data row4 col6" >0.836210</td>
#       <td id="T_7f55b_row4_col7" class="data row4 col7" >0.685877</td>
#       <td id="T_7f55b_row4_col8" class="data row4 col8"

# %% [markdown]
# #### Conclusions (variables to remove > 0.7 correlation)
#  - commute OR trips_express
#  - commute OR total_driver_payout
#  - commute OR total_matches
#  - trips_express OR total_driver_payout
#  - trips_express OR total_matches
#  - trips_express OR total_double_matches
#  - total_driver_payout OR total_matches
#  - total_matches OR total_double_matches

# %% [markdown]
# ## FIT MODEL - statsmodels

# %%
model2_treat = ols("rider_cancellations ~  total_matches + weekend", df_treatment).fit() # 5 mins
model2_treat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     rider_cancellations   R-squared:                       0.746
# Model:                             OLS   Adj. R-squared:                  0.737
# Method:                  Least Squares   F-statistic:                     88.04
# Date:                 Fri, 20 May 2022   Prob (F-statistic):           1.42e-18
# Time:                         08:49:58   Log-Likelihood:                -296.84
# No. Observations:                   63   AIC:                             599.7
# Df Residuals:                       60   BIC:                             606.1
# Df Model:                            2
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        13.3415     15.779      0.846      0.401     -18.221      44.904
# total_matches     0.0755      0.006     12.317      0.000       0.063       0.088
# weekend         -25.7287      7.757     -3.317      0.002     -41.244     -10.213
# ==============================================================================
# Omnibus:                        6.044   Durbin-Watson:                   2.263
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                5.482
# Skew:                           0.715   Prob(JB):                       0.0645
# Kurtosis:                       3.203   Cond. No.                     1.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### EVALUATE MODEL

# %% [markdown]
#  - Adjusted R-Squared -> 73.7%
#      - this model explains 73.7% of the variance in the rider_cancellations variable
#  - P-value -> below 0.05 for both variables used
#      - both variables used are statistically significant using a significance level of 5%

# %% [markdown]
# #### Residual plot of errors (y), ind variable (x) - zero mean of errors and autocorrelation of errors -- should average to 0

# %%
# Residual plot for model1
sns.scatterplot(x = model2_treat.fittedvalues, y = model2_treat.resid)
plt.ylabel('residual')
plt.axhline(0)

## The residuals seems to average to around 0, showing this does not represent a problem in model2_treat

# %%
#define figure size
fig = plt.figure(figsize=(12,8))

#produce regression plots
fig = sm.graphics.plot_regress_exog(model2_treat, 'total_matches', fig=fig)

# %% [markdown]
# ## CONTROL GROUP (2 MINUTES)

# %%
# Generate scatter plots for each numerical variable in the 5 minute dataframe against the dependent variable
for col in df_control.columns:
    if col in ('trips_pool', 'trips_express', 'total_driver_payout', 'total_matches', 'total_double_matches'):
        sns.scatterplot(data = df_control, x = 'rider_cancellations', y = col)
        plt.show()

# %% [markdown]
# #### Relationships between each independent variable and the dependent variable based on scatter plots
#
#  - trips_pool -> weak linear relationship
#  - trips_express -> linear relationship
#  - total_driver_payout -> linear relationship
#  - total_matches -> linear relationship
#  - total_double_matches -> linear relationship

# %% [markdown]
# ### Check for Multicollinearity

# %%
# Correlation matrix of numerical data
df_control.select_dtypes(exclude = 'object').corr().style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_b2fb4_row0_col0, #T_b2fb4_row0_col1, #T_b2fb4_row0_col2, #T_b2fb4_row0_col3, #T_b2fb4_row0_col4, #T_b2fb4_row0_col5, #T_b2fb4_row0_col6, #T_b2fb4_row0_col7, #T_b2fb4_row0_col8, #T_b2fb4_row1_col0, #T_b2fb4_row2_col0, #T_b2fb4_row3_col0, #T_b2fb4_row4_col0, #T_b2fb4_row5_col0, #T_b2fb4_row6_col0, #T_b2fb4_row7_col0, #T_b2fb4_row8_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col1, #T_b2fb4_row2_col2, #T_b2fb4_row3_col3, #T_b2fb4_row4_col4, #T_b2fb4_row5_col5, #T_b2fb4_row6_col6, #T_b2fb4_row7_col7, #T_b2fb4_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b2fb4_row1_col3, #T_b2fb4_row6_col7 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col5, #T_b2fb4_row4_col1, #T_b2fb4_row5_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col6, #T_b2fb4_row3_col1, #T_b2fb4_row4_col3, #T_b2fb4_row5_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_b2fb4_row1_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_b2fb4_row1_col8, #T_b2fb4_row8_col1, #T_b2fb4_row8_col2, #T_b2fb4_row8_col3, #T_b2fb4_row8_col4, #T_b2fb4_row8_col5, #T_b2fb4_row8_col6, #T_b2fb4_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b2fb4_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b2fb4_row2_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b2fb4_row2_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b2fb4_row2_col5 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b2fb4_row2_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b2fb4_row2_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b2fb4_row2_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b2fb4_row3_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b2fb4_row3_col4, #T_b2fb4_row3_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_b2fb4_row3_col6, #T_b2fb4_row6_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_b2fb4_row3_col7 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_b2fb4_row3_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b2fb4_row4_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b2fb4_row4_col5, #T_b2fb4_row5_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_b2fb4_row4_col6 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_b2fb4_row4_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_b2fb4_row4_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b2fb4_row5_col1, #T_b2fb4_row6_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_b2fb4_row5_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b2fb4_row5_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_b2fb4_row5_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b2fb4_row6_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_b2fb4_row6_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b2fb4_row6_col5, #T_b2fb4_row7_col3 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_b2fb4_row6_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b2fb4_row7_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b2fb4_row7_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b2fb4_row7_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b2fb4_row7_col5 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_b2fb4_row7_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_b2fb4_row7_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# </style>
# <table id="T_b2fb4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treat</th>
#       <th class="col_heading level0 col1" >commute</th>
#       <th class="col_heading level0 col2" >trips_pool</th>
#       <th class="col_heading level0 col3" >trips_express</th>
#       <th class="col_heading level0 col4" >rider_cancellations</th>
#       <th class="col_heading level0 col5" >total_driver_payout</th>
#       <th class="col_heading level0 col6" >total_matches</th>
#       <th class="col_heading level0 col7" >total_double_matches</th>
#       <th class="col_heading level0 col8" >weekend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2fb4_level0_row0" class="row_heading level0 row0" >treat</th>
#       <td id="T_b2fb4_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b2fb4_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_b2fb4_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b2fb4_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_b2fb4_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_b2fb4_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_b2fb4_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_b2fb4_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_b2fb4_row0_col8" class="data row0 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b2fb4_level0_row1" class="row_heading level0 row1" >commute</th>
#       <td id="T_b2fb4_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_b2fb4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b2fb4_row1_col2" class="data row1 col2" >0.304780</td>
#       <td id="T_b2fb4_row1_col3" class="data row1 col3" >0.776082</td>
#       <td id="T_b2fb4_row1_col4" class="data row1 col4" >0.767315</td>
#       <td id="T_b2fb4_row1_col5" class="data row1 col5" >0.789452</td>
#       <td id="T_b2fb4_row1_col6" class="data row1 col6" >0.807443</td>
#       <td id="T_b2fb4_row1_col7" class="data row1 col7" >0.594606</td>
#       <td id="T_b2fb4_row1_col8" class="data row1 col8" >-0.274721</td>
#     </tr>
#     <tr>
#       <th id="T_b2fb4_level0_row2" class="row_heading level0 row2" >trips_pool</th>
#       <td id="T_b2fb4_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_b2fb4_row2_col1" class="data row2 col1" >0.304780</td>
#       <td id="T_b2fb4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b2fb4_row2_col3" class="data row2 col3" >0.180944</td>
#       <td id="T_b2fb4_row2_col4" class="data row2 col4" >0.457141</td>
#       <td id="T_b2fb4_row2_col5" class="data row2 col5" >0.563094</td>
#       <td id="T_b2fb4_row2_col6" class="data row2 col6" >0.191395</td>
#       <td id="T_b2fb4_row2_col7" class="data row2 col7" >0.151455</td>
#       <td id="T_b2fb4_row2_col8" class="data row2 col8" >-0.267218</td>
#     </tr>
#     <tr>
#       <th id="T_b2fb4_level0_row3" class="row_heading level0 row3" >trips_express</th>
#       <td id="T_b2fb4_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_b2fb4_row3_col1" class="data row3 col1" >0.776082</td>
#       <td id="T_b2fb4_row3_col2" class="data row3 col2" >0.180944</td>
#       <td id="T_b2fb4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b2fb4_row3_col4" class="data row3 col4" >0.814604</td>
#       <td id="T_b2fb4_row3_col5" class="data row3 col5" >0.814489</td>
#       <td id="T_b2fb4_row3_col6" class="data row3 col6" >0.960362</td>
#       <td id="T_b2fb4_row3_col7" class="data row3 col7" >0.821643</td>
#       <td id="T_b2fb4_row3_col8" class="data row3 col8" >-0.060869</td>
#     </tr>
#     <tr>
#       <th id="T_b2fb4_level0_row4" class="row_heading level0 row4" >rider_cancellations</th>
#       <td id="T_b2fb4_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_b2fb4_row4_col1" class="data row4 col1" >0.767315</td>
#       <td id="T_b2fb4_row4_col2" class="data row4 col2" >0.457141</td>
#       <td id="T_b2fb4_row4_col3" class="data row4 col3" >0.814604</td>
#       <td id="T_b2fb4_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b2fb4_row4_col5" class="data row4 col5" >0.828348</td>
#       <td id="T_b2fb4_row4_col6" class="data row4 col6" >0.806330</td>
#       <td id="T_b2fb4_row4_col7" class="data row4 col7" >0.659194</td>
#       <td id="T_b2fb4_row4_col8" class="data row4 col8" >-0.175270</td>
#     </tr>
#     <tr>
#       <th id="T

# %% [markdown]
# #### Conclusions (variables to remove > 0.7 correlation)
#  - commute OR trips_express
#  - commute OR total_driver_payout
#  - commute OR total_matches
#  - trips_express OR total_driver_payout
#  - trips_express OR total_matches
#  - trips_express OR total_double_matches
#  - total_driver_payout OR total_matches
#  - total_driver_payout OR total_double_matches
#  - total_matches OR total_double_matches

# %% [markdown]
# ## FIT MODEL - statsmodels

# %%
model3_control = ols("rider_cancellations ~ trips_pool + total_matches + weekend", df_control).fit() # 2 mins
model3_control.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     rider_cancellations   R-squared:                       0.746
# Model:                             OLS   Adj. R-squared:                  0.733
# Method:                  Least Squares   F-statistic:                     57.69
# Date:                 Fri, 20 May 2022   Prob (F-statistic):           1.53e-17
# Time:                         08:54:20   Log-Likelihood:                -287.68
# No. Observations:                   63   AIC:                             583.4
# Df Residuals:                       59   BIC:                             591.9
# Df Model:                            3
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -62.7605     21.628     -2.902      0.005    -106.038     -19.483
# trips_pool        0.0613      0.014      4.465      0.000       0.034       0.089
# total_matches     0.0553      0.005     11.130      0.000       0.045       0.065
# weekend          -2.1830      6.969     -0.313      0.755     -16.128      11.762
# ==============================================================================
# Omnibus:                        0.369   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.832   Jarque-Bera (JB):                0.454
# Skew:                           0.170   Prob(JB):                        0.797
# Kurtosis:                       2.760   Cond. No.                     2.17e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### EVALUATE MODEL

# %% [markdown]
#  - Adjusted R-Squared -> 73.3%
#      - this model explains 73.3% of the variance in the rider_cancellations variable
#  - P-value -> above 0.05 for the weekend variable
#      - the weekend variable is not statistically significant in the control group model
#      - all other variables used are statistically significant using a significance level of 5%

# %% [markdown]
# #### Residual plot of errors (y), ind variable (x) - zero mean of errors and autocorrelation of errors -- should average to 0

# %%
# Residual plot for model1
sns.scatterplot(x = model1.fittedvalues, y = model1.resid)
plt.ylabel('residual')
plt.axhline(0)

## The residuals seems to average to around 0, showing this does not represent a problem in model1

# %%
#define figure size
fig = plt.figure(figsize=(12,8))

#produce regression plots
fig = sm.graphics.plot_regress_exog(model3_control, 'trips_pool', fig=fig)

# %%
#define figure size
fig2 = plt.figure(figsize=(12,8))

#produce regression plots
fig2 = sm.graphics.plot_regress_exog(model3_control, 'total_matches', fig=fig2)

# %% [markdown]
# # FIT MODELS - scikit-learn

# %% [markdown]
# ## Fit Original Data Regression Model - 5 minutes wait time

# %%
# Train / Test Split
X = data[['trips_pool', 'total_matches', 'weekend']]
y = data['rider_cancellations']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# Fit training data
LReg = LinearRegression()
LReg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict test set results
y_pred = LReg.predict(X_test)

# %%
# Calculate RMSE to compare models
rmse = math.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE (root mean squared error) of the model: ', np.round(rmse, 4))

# Lower RMSE value = better fit
# Out:
# RMSE (root mean squared error) of the model:  27.6784

# %% [markdown]
# ## Fit Treatment Group Regression Model - 5 minutes wait time

# %%
# Train / Test Split
X_treatment = df_treatment[['total_matches', 'weekend']]
y_treatment = df_treatment['rider_cancellations']
X_train_treatment, X_test_treatment, y_train_treatment, y_test_treatment = train_test_split(X_treatment, y_treatment, test_size = 0.3, random_state = 42)

# %%
# Fit training data
LReg_treatment = LinearRegression()
LReg_treatment.fit(X_train_treatment, y_train_treatment)
# Out:
# LinearRegression()

# %%
# Predict test set results
y_pred_treatment = LReg_treatment.predict(X_test_treatment)

# %%
# Calculate RMSE to compare models
rmse = math.sqrt(mean_squared_error(y_test_treatment, y_pred_treatment))
print('RMSE (root mean squared error) of the treatment group model: ', np.round(rmse, 4))

# Lower RMSE value = better fit
# Out:
# RMSE (root mean squared error) of the treatment group model:  23.5941

# %% [markdown]
# ## Fit Control Group Regression Model - 2 minutes wait time

# %%
# Train / Test Split
X_control = df_control[['trips_pool', 'total_matches', 'weekend']]
y_control = df_control['rider_cancellations']
X_train_control, X_test_control, y_train_control, y_test_control = train_test_split(X_control, y_control, test_size = 0.3, random_state = 42)

# %%
# Fit training data
LReg_control = LinearRegression()
LReg_control.fit(X_train_control, y_train_control)
# Out:
# LinearRegression()

# %%
# Predict test set results
y_pred_control = LReg_control.predict(X_test_control)

# %%
# Calculate RMSE to compare models
rmse = math.sqrt(mean_squared_error(y_test_control, y_pred_control))
print('RMSE (root mean squared error) of the control group model: ', np.round(rmse, 4))

# Lower RMSE value = better fit
# Out:
# RMSE (root mean squared error) of the control group model:  27.9168

# %% [markdown]
# ## Assignment Instructions: You have been tasked with analyzing whether Uber should extend the Express Pool wait time from 2 minutes to 5 minutes.
#  1. Generate a model which can be used by Uber to predict cancellations. Estimate your model using a regression technique of your choosing.
#  2. Use the Jupyter Notebook template I provided as a jumping off point to help you get started. Your analysis should address the following:
#      - Customer experience: what four variables would you use to capture how the customer experience is affected by the increase in wait times?
#      - Efficiency metrics: what 3 variables would you use to capture how efficiency is affected by the increase in wait times?
#      - Is there a difference in the customer experience metrics and efficiency metrics between the 2- and 5-minute wait time groups?
#      - What other differences exist? Are there differences between commuting hours (rush hours) and non-commuting hours (non-rush hours). If so, how does this affect your recommendations?
#      - Provide statistical evidence to back up your conclusions.
#  3. Discuss your results. What do your results imply for Uber? What course of action would you recommend for Uber?
#
#  - Bonus points: Generate a calculation that will tell Uber lose from keeping the wait time.

# %% [markdown]
# ## NEXT TO DO
#  - explore weekend or not weekend variable and look for changes (redo exploratory analysis based on the addition of that variable) -- DONE
#  - make sure exploratory analysis in all regressions are done to check for linear regression assumptions and evaluate models -- DONE
#  - fit and evaluate models using scikit learn (add RMSE) (so evaluation metrics used are adjusted r-squared and RMSE) -- DONE
#  - answer questions above
#  - write report
#       1. Goal of the project and differences between products and treatment vs control (executive summary)
#       2. FOR EACH REGRESSION
#          - 2a. Exploratory analysis pre-regression - describe any info about data + discuss some linear regression assumptions + addition of new variables
#          - 2b. Discuss model results
#          - 2c. Exploratory analysis post-regression to check for more linear regression assumptions
#       3. Answer questions above
#       4. Conclusion / Final thoughts
